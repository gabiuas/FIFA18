# %% [markdown]
# # Algoritmo Cluster - FIFA 18

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

import re
print('Esperamos trabalhar no diretório')
print(os.getcwd())

#Complete
complete = pd.read_csv('CompleteDataset.csv',sep=',')

eu= pd.DataFrame({"Name":complete.Name})

 

 

eu["Overall"] = complete["Overall"]
eu["Nationality"] = complete["Nationality"]
eu["Club"] = complete["Club"]
eu["Preferred Positions"] = complete["Preferred Positions"]
eu["Long shots"] = complete["Long shots"]
eu["Finishing"] = complete["Finishing"]
eu["Short passing"] = complete["Short passing"]
eu["Ball control"] = complete["Ball control"]
eu["Dribbling"] = complete["Dribbling"]
eu["Long passing"] = complete["Long passing"]
eu["Interceptions"] = complete["Interceptions"]
eu["Marking"] = complete["Marking"]
eu["Standing tackle"] = complete["Standing tackle"]
eu["Sliding tackle"] = complete["Sliding tackle"]
eu["Strength"] = complete["Strength"]
eu["Positioning"] = complete["Volleys"]

eu = eu.fillna(0)  

 

 

A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
H=[]
I=[]
J=[]
K=[]
L=[]

a=len(eu["Name"])

for e in range(a):
    A.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Long shots"][e]))))
    B.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Finishing"][e]))))
    C.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Short passing"][e]))))
    D.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Ball control"][e]))))
    E.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Dribbling"][e]))))
    F.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Long passing"][e]))))
    G.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Interceptions"][e]))))
    H.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Marking"][e]))))
    I.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Standing tackle"][e]))))
    J.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Sliding tackle"][e]))))
    K.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Strength"][e]))))
    L.append((sum(int(x) for x in re.findall(r'[0-9]+', eu["Positioning"][e]))))
    
    
eu["Long shots"] = pd.Series(A)
eu["Finishing"] = pd.Series(B)
eu["Short passing"] = pd.Series(C)
eu["Ball control"] = pd.Series(D)
eu["Dribbling"] = pd.Series(E)
eu["Long passing"] = pd.Series(F)
eu["Interceptions"] = pd.Series(G)
eu["Marking"] = pd.Series(H)
eu["Standing tackle"] = pd.Series(I)
eu["Sliding tackle"] = pd.Series(J)
eu["Strength"] = pd.Series(K)
eu["Positioning"] = pd.Series(L)

 

 

ataque=[]
for e in range(a):
    ataq=((eu["Long shots"][e]+eu["Finishing"][e]+eu["Short passing"][e]+eu["Ball control"][e]+eu["Dribbling"][e]+eu["Long passing"][e]+eu["Positioning"][e])/7)
    ataque.append(ataq)


defesa=[]
for e in range(a):
    defe=((eu["Interceptions"][e]+eu["Marking"][e]+eu["Standing tackle"][e]+eu["Sliding tackle"][e])/4)
    defesa.append(defe)


eu["ATAQUE"] = pd.Series(ataque)
eu["DEFESA"] = pd.Series(defesa)

 

JoA=[]
JoD=[]

for e in range(a):
    if "RAM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "CAM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "LAM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "RCM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "CM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "LCM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "RM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "LM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "RDM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "CDM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
    elif "LDM" in eu['Preferred Positions'][e]:
        JoA.append(eu["ATAQUE"][e])
        JoD.append(eu["DEFESA"][e])
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Pedro Suarez\Documents\2 semestre\Ciências dos dados\Projeto 3
# C:\Users\Pedro Suarez\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
######### MUDAR ESSA PARTE PARA MUDAR LAYOUT


from tkinter import *



class ScaleTest :

    def CloseMe(self) :
        self.value = self.scale.get()
        self.value2 = self.scale2.get()
        self.value3 = self.scale3.get()
        self.value4 = self.scale4.get()
        self.value5 = self.scale5.get()
        self.value6 = self.scale6.get()
        self.value7 = self.scale7.get()
        self.value8 = self.scale8.get()
        self.value9 = self.scale9.get()
        self.value10 = self.scale10.get()
        self.value11 = self.scale11.get()
        self.root.destroy()

    def ShowTheValue(self, args) :
        self.value_label["text"] = str(self.scale.get())
        self.value_label2["text"] = str(self.scale2.get())
        self.value_label3["text"] = str(self.scale3.get())
        self.value_label4["text"] = str(self.scale4.get())
        self.value_label5["text"] = str(self.scale5.get())
        self.value_label6["text"] = str(self.scale6.get())
        self.value_label7["text"] = str(self.scale7.get())
        self.value_label8["text"] = str(self.scale8.get())
        self.value_label9["text"] = str(self.scale9.get())
        self.value_label10["text"] = str(self.scale10.get())
        self.value_label11["text"] = str(self.scale11.get())
    
    


   
    
    def __init__(self) :
        
        self.root = Tk()
        self.root.configure(background='forest green')
        self.root.geometry("1450x780")
        Label(self.root, text="Qual tipo de meia você é ?",font=("Helvetica", 46),fg="black",background='forest green').place(x=416, y=10)
        #Label(self.root, text="",font=("Helvetica", 46),fg="navy",background='green2').place(x=568, y=65)


    
        Label(self.root, text="Chute de Longe",font=("Helvetica", 30),fg="black",background='forest green').place(x=100, y=155)
        self.value = 0
        self.scale = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale.place(x=100, y=205)
        self.value_label = Label( self.root, text="0" )
        
       
        

        Label(self.root, text="Finalização",font=("Helvetica", 30),fg="black",background='forest green').place(x=100, y=285)
        self.value2 = 0
        self.scale2 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale2.place(x=100, y=335)
        self.value_label2 = Label( self.root, text="0" )
        

        Label(self.root, text="Passe Curto",font=("Helvetica", 30),fg="black",background='forest green').place(x=100, y=425)
        self.value3 = 0
        self.scale3 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale3.place(x=100, y=475)
        self.value_label3 = Label( self.root, text="0" )
        


        Label(self.root, text="Controle de Bola",font=("Helvetica", 30),fg="black",background='forest green').place(x=100, y=565)
        self.value4 = 0
        self.scale4 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale4.place(x=100, y=615)
        self.value_label4 = Label( self.root, text="0" )
        


        Label(self.root, text="Drible",font=("Helvetica", 30),fg="black",background='forest green').place(x=525, y=155)
        self.value5 = 0
        self.scale5 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale5.place(x=525, y=205)
        self.value_label5 = Label( self.root, text="0" )
        


        
        Label(self.root, text="Passe Longo",font=("Helvetica", 30),fg="black",background='forest green').place(x=525, y=285)
        self.value6 = 0
        self.scale6 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale6.place(x=525, y=335)
        self.value_label6 = Label( self.root, text="0" )
        


        Label(self.root, text="Posicionamento",font=("Helvetica", 30),fg="black",background='forest green').place(x=525, y=425)
        self.value7 = 0
        self.scale7 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale7.place(x=525, y=475)
        self.value_label7 = Label( self.root, text="0" )
        


        Label(self.root, text="Marcação",font=("Helvetica", 30),fg="black",background='forest green').place(x=525, y=565)
        self.value8 = 0
        self.scale8 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale8.place(x=525, y=615)
        self.value_label8 = Label( self.root, text="0" )
        


        Label(self.root, text="Desarme em pé",font=("Helvetica", 30),fg="black",background='forest green').place(x=950, y=155)
        self.value9 = 0
        self.scale9 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue ,length=380,background='green3')
        self.scale9.place(x=950, y=205)
        self.value_label9 = Label( self.root, text="0" )
        


        Label(self.root, text="Desarme deslizando",font=("Helvetica", 30),fg="black",background='forest green').place(x=950, y=285)
        self.value10 = 0
        self.scale10 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue,length=380,background='green3')
        self.scale10.place(x=950, y=335)
        self.value_label10 = Label( self.root, text="0" )
        


        Label(self.root, text="Interceptação",font=("Helvetica", 30),fg="black",background='forest green').place(x=950, y=425)
        self.value11 = 0
        self.scale11 = Scale( self.root, from_=0, to=100, orient=HORIZONTAL,showvalue=True,command=self.ShowTheValue,length=380,background='green3')
        self.scale11.place(x=950, y=475)
        self.value_label11 = Label( self.root, text="0" )
        
        

        Button( self.root, text="ENTER", command=self.CloseMe, width = 28 ,fg="black",background='green3').place(x=1000, y=630)
        self.root.mainloop()


st = ScaleTest()
Long_shots = st.value
Finishing = st.value2
Short_passing = st.value3
Ball_control = st.value4
Dribbling = st.value5
Long_passing = st.value6
Positioning = st.value7
Marking = st.value8
Standing_tackle = st.value9
Strength = st.value10
Interceptions = st.value11



meu_A=(Long_shots+Finishing+Short_passing+Ball_control+Dribbling+Long_passing+Positioning)/7
meu_D=(Interceptions+Marking+Standing_tackle+Strength)/4



###########DAQUI PARA BAIXO É PARA O GRÁFICO, NÃO PRECISA MUDAR NADA



from sklearn.cluster import KMeans
from sklearn.cluster import Birch

eu.head()
times=[]
for e in range(a):
    if eu["Club"][e] not in times:
        times.append(eu["Club"][e])
        


F=[]
for e in range(len(JoA)):
    f=[]
    f.append(JoD[e])
    f.append(JoA[e])
    
    F.append(f)



X=np.array(F)

km = KMeans(n_clusters=4)

km.fit(X)

C = km.cluster_centers_
label = km.labels_
colors=['r.','b.','g.','c.']

# print('')
# print('')
# print('LEGENDA:')
# print('Roxo - Attacking Midfielder')
# print('Azul - Left Midfielder, Center Midfielder & Right Midfielder')
# print('Laranja - Defensive Midfielder')
# print('Verde - Polivalente')

import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))
for l in np.unique(label):
    plt.scatter(X[label == l, 0], X[label == l, 1],color=plt.cm.jet(float(l) / np.max(label + 1)),s=20, edgecolor='k')
plt.scatter(meu_D,meu_A,300,marker=(5, 1),c='red')
plt.xlabel('DEFESA')
plt.ylabel('ATAQUE')
plt.title('TIPO DE MEIAS')
plt.show()
